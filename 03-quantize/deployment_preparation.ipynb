# %% [markdown]
# # Deployment preparation
#
# In this notebook we will perform several supplementary actions to prepare our segmentation model for the deployment. Whereas none of the following actions is strictly necessary, we recommend the presented approach, as it makes the deployment with contenerized Vitis AI tools easier in the next step. Sharing the main codebase between the repository and the Vitis AI container can be tricky, as the deployment environment is rather constrained. In this notebook we will prepare the model and quantization calibration data in advance.
#
# The Vitis AI deployment procedure requires several elements:
# * The model to be deployed (pretrained, stripped from any 3rd party dependencies if possible).
# * A *quantization calibration dataset* derived from the training input samples that will be used by the model quantizer.
# * It is possible (but not necessary) to evalaute the quantized model before it is deployed to the target platform; in this notebook we will prepare the test subset of our dataset for post-quantization evaluation too.

# %%
from pathlib import Path

import h5py
import pytorch_lightning as pl
import torch
from torchsummary import summary
from tqdm import tqdm

from sml_tutorials_ml_deployment.datasets import DeepGlobeLandCover, transforms
from sml_tutorials_ml_deployment.training import SegmentationTask
from sml_tutorials_ml_deployment.model import Unet

# %%
# Reproducibility
pl.seed_everything(42)
# Out:
# Seed set to 42
# 42

# %% [markdown]
# ## Preparing the quantization dataset
#
# The model quantizer needs to be fed with a dataset that is representative of the data that the model will be used with. To make the quantization process inside Vitis AI container easier we can prepare the quantization subset in advance and save it in a h5 file.
#
# Vitis AI documentation advises to use a quantization dataset with 100 up to 1000 samples derived from the train subset. The train GT labels are not required in the quantization process.

# %%
QUANTIZATION_SAMPLES_NUM = 250

# %% [markdown]
# It is best to preprocess all samples now and store them in a h5 file ready for inference. If you use complex transforms in your preprocssing, it may be challanging to to run them in the Vitis AI container.

# %%
train_ds = DeepGlobeLandCover(root_dir=Path("../../dataset/deep_globe_patched"), split="training", transforms=transforms)
test_ds = DeepGlobeLandCover(root_dir=Path("../../dataset/deep_globe_patched"), split="test", transforms=transforms)
num_classes = len(train_ds.CLASSES)

# %% [markdown]
# Now we can draw 250 preprocessed sample inputs from our dataset. Notice that we only save model inputs – the ground truth masks are not needed by the quantizer.

# %%
output_dir = Path("../../output/03-quantize")
output_dir.mkdir(parents=True, exist_ok=True)

# %%
with h5py.File(output_dir / "quantization_samples.h5", "w") as f:
    calibration = f.create_group("calibration")
    test = f.create_group("test")

quantization_indices = torch.randperm(len(train_ds))[:QUANTIZATION_SAMPLES_NUM]
for sample_idx in tqdm(quantization_indices, desc="Quantization samples"):
    with h5py.File(output_dir / "quantization_samples.h5", "a") as f:
        sample = train_ds[sample_idx]
        f["calibration"].create_dataset(f"{sample['id']}", data=sample["image"])

for sample in tqdm(test_ds, desc="Test samples"):
    with h5py.File(output_dir / "quantization_samples.h5", "a") as f:
        f["test"].create_dataset(f"{sample['id']}", data=sample["image"])
# Out:
# Quantization samples: 100%|██████████| 250/250 [00:10<00:00, 24.63it/s]
# Test sampples: 100%|██████████| 3000/3000 [02:00<00:00, 24.81it/s]

# %% [markdown]
# Notice that you can also load the samples from you data directory and preprocess them directly in the docker environment omitting the process we have just shown. However, we recommend the demonstrated approach, as it allows you to do any kind of complex data processing in advance on you host enviroment.
#
# ## Saving model weights
#
# If you have been training your model with some 3rd party Python modules or tools it is a good time to try to make it as standalone as possible. Importing custom libraries into the deployment environement may be rather challenging. In the case of our demo model we have used PyTorch Lightning to speed up the training process. We will extract the model weights from the Lightning training checkpoint and save them in a vanilla PyTorch state dict that can be easily loaded inside Vitis AI docker container with pure PyTorch.

# %%
MODEL_CHECKPOINT_PATH = Path("../../output/02-train/model.ckpt")

# %%
task = SegmentationTask.load_from_checkpoint(MODEL_CHECKPOINT_PATH, model=Unet(num_classes), map_location="cpu")
model = task.model

# %%
torch.save(model.state_dict(), output_dir / "state_dict.pt")

# %% [markdown]
# Finally, we can double check whether our final model architecture is compatible with the deployment tools. We can print the model summary to obtain (a rather lengthy) list of all elements in the network. You can check whether the model layers are supported by Vitis AI by comparing it against the [documentation][1].
#
# Incompatible layers can be delegated to the CPU, in this case you have to reimplement them on the edge by yourself (presumably in C++ or Python). This is an advanced technique that will also likley lead to performance overhead. It is best to design you network with full Vitis AI acceleration in mind.
#
# [1]: https://docs.amd.com/r/en-US/ug1414-vitis-ai/Operators-Supported-by-PyTorch

# %%
demo_input = train_ds[0]["image"]
demo_batch = demo_input.unsqueeze(0)
print(summary(model, demo_batch, depth=10))
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# ├─GraphModuleImpl: 1-1                                  [[-1, 512, 16, 16]]       --
# ├─ResNet: 1                                             []                        --
# |    └─Conv2d: 2-1                                      [-1, 64, 256, 256]        9,408
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Conv2d: 2-2                                      [-1, 64, 256, 256]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─BatchNorm2d: 2-3                                 [-1, 64, 256, 256]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─BatchNorm2d: 2-4                                 [-1, 64, 256, 256]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─ReLU: 2-5                                        [-1, 64, 256, 256]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─ReLU: 2-6                                        [-1, 64, 256, 256]        --
# ├─ResNet: 1                                             []                        --
# |    └─MaxPool2d: 2-7                                   [-1, 64, 128, 128]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─MaxPool2d: 2-8                                   [-1, 64, 128, 128]        --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-1                            [-1, 64, 128, 128]        36,864
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-2                            [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-3                       [-1, 64, 128, 128]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-4                       [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-5                              [-1, 64, 128, 128]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-6                              [-1, 64, 128, 128]        --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-7                            [-1, 64, 128, 128]        36,864
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-8                            [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-9                       [-1, 64, 128, 128]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-10                      [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-11                             [-1, 64, 128, 128]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-12                             [-1, 64, 128, 128]        --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-13                           [-1, 64, 128, 128]        36,864
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-14                           [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-15                      [-1, 64, 128, 128]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-16                      [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-17                             [-1, 64, 128, 128]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-18                             [-1, 64, 128, 128]        --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-19                           [-1, 64, 128, 128]        36,864
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-20                           [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-21                      [-1, 64, 128, 128]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-22                      [-1, 64, 128, 128]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-23                             [-1, 64, 128, 128]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-24                             [-1, 64, 128, 128]        --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-25                           [-1, 128, 64, 64]         73,728
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-26                           [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-27                      [-1, 128, 64, 64]         256
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-28                      [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-29                             [-1, 128, 64, 64]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-30                             [-1, 128, 64, 64]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-31                           [-1, 128, 64, 64]         147,456
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-32                           [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-33                      [-1, 128, 64, 64]         256
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-34                      [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─Conv2d: 5-1                       [-1, 128, 64, 64]         8,192
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─Conv2d: 5-2                       [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─BatchNorm2d: 5-3                  [-1, 128, 64, 64]         256
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─BatchNorm2d: 5-4                  [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-35                             [-1, 128, 64, 64]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-36                             [-1, 128, 64, 64]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-37                           [-1, 128, 64, 64]         147,456
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-38                           [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-39                      [-1, 128, 64, 64]         256
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-40                      [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-41                             [-1, 128, 64, 64]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-42                             [-1, 128, 64, 64]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-43                           [-1, 128, 64, 64]         147,456
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-44                           [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-45                      [-1, 128, 64, 64]         256
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-46                      [-1, 128, 64, 64]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-47                             [-1, 128, 64, 64]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-48                             [-1, 128, 64, 64]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-49                           [-1, 256, 32, 32]         294,912
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-50                           [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-51                      [-1, 256, 32, 32]         512
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-52                      [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-53                             [-1, 256, 32, 32]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-54                             [-1, 256, 32, 32]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-55                           [-1, 256, 32, 32]         589,824
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-56                           [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-57                      [-1, 256, 32, 32]         512
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-58                      [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─Conv2d: 5-5                       [-1, 256, 32, 32]         32,768
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─Conv2d: 5-6                       [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─BatchNorm2d: 5-7                  [-1, 256, 32, 32]         512
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─BatchNorm2d: 5-8                  [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-59                             [-1, 256, 32, 32]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-60                             [-1, 256, 32, 32]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-61                           [-1, 256, 32, 32]         589,824
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-62                           [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-63                      [-1, 256, 32, 32]         512
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-64                      [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-65                             [-1, 256, 32, 32]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-66                             [-1, 256, 32, 32]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-67                           [-1, 256, 32, 32]         589,824
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-68                           [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-69                      [-1, 256, 32, 32]         512
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-70                      [-1, 256, 32, 32]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-71                             [-1, 256, 32, 32]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-72                             [-1, 256, 32, 32]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-73                           [-1, 512, 16, 16]         1,179,648
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-74                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-75                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-76                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-77                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-78                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-79                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-80                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-81                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-82                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─Conv2d: 5-9                       [-1, 512, 16, 16]         131,072
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─Conv2d: 5-10                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─BatchNorm2d: 5-11                 [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─BatchNorm2d: 5-12                 [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-83                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-84                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-85                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-86                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-87                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-88                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-89                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-90                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-91                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-92                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-93                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-94                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-95                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-96                             [-1, 512, 16, 16]         --
# ├─Decoder: 1-2                                          [-1, 32, 512, 512]        --
# |    └─ModuleList: 2                                    []                        --
# |    |    └─DecoderBlock: 3-1                           [-1, 512, 32, 32]         --
# |    |    |    └─Upsample: 4-97                         [-1, 512, 32, 32]         --
# |    |    |    └─Sequential: 4-98                       [-1, 512, 32, 32]         --
# |    |    |    |    └─ConvBlock: 5-13                   [-1, 512, 32, 32]         --
# |    |    |    |    |    └─Sequential: 6-1              [-1, 512, 32, 32]         --
# |    |    |    |    |    |    └─Conv2d: 7-1             [-1, 512, 32, 32]         3,538,944
# |    |    |    |    |    |    └─BatchNorm2d: 7-2        [-1, 512, 32, 32]         1,024
# |    |    |    |    |    |    └─ReLU: 7-3               [-1, 512, 32, 32]         --
# |    |    |    |    └─ConvBlock: 5-14                   [-1, 512, 32, 32]         --
# |    |    |    |    |    └─Sequential: 6-2              [-1, 512, 32, 32]         --
# |    |    |    |    |    |    └─Conv2d: 7-4             [-1, 512, 32, 32]         2,359,296
# |    |    |    |    |    |    └─BatchNorm2d: 7-5        [-1, 512, 32, 32]         1,024
# |    |    |    |    |    |    └─ReLU: 7-6               [-1, 512, 32, 32]         --
# |    |    └─DecoderBlock: 3-2                           [-1, 256, 64, 64]         --
# |    |    |    └─Upsample: 4-99                         [-1, 512, 64, 64]         --
# |    |    |    └─Sequential: 4-100                      [-1, 256, 64, 64]         --
# |    |    |    |    └─ConvBlock: 5-15                   [-1, 256, 64, 64]         --
# |    |    |    |    |    └─Sequential: 6-3              [-1, 256, 64, 64]         --
# |    |    |    |    |    |    └─Conv2d: 7-7             [-1, 256, 64, 64]         1,474,560
# |    |    |    |    |    |    └─BatchNorm2d: 7-8        [-1, 256, 64, 64]         512
# |    |    |    |    |    |    └─ReLU: 7-9               [-1, 256, 64, 64]         --
# |    |    |    |    └─ConvBlock: 5-16                   [-1, 256, 64, 64]         --
# |    |    |    |    |    └─Sequential: 6-4              [-1, 256, 64, 64]         --
# |    |    |    |    |    |    └─Conv2d: 7-10            [-1, 256, 64, 64]         589,824
# |    |    |    |    |    |    └─BatchNorm2d: 7-11       [-1, 256, 64, 64]         512
# |    |    |    |    |    |    └─ReLU: 7-12              [-1, 256, 64, 64]         --
# |    |    └─DecoderBlock: 3-3                           [-1, 128, 128, 128]       --
# |    |    |    └─Upsample: 4-101                        [-1, 256, 128, 128]       --
# |    |    |    └─Sequential: 4-102                      [-1, 128, 128, 128]       --
# |    |    |    |    └─ConvBlock: 5-17                   [-1, 128, 128, 128]       --
# |    |    |    |    |    └─Sequential: 6-5              [-1, 128, 128, 128]       --
# |    |    |    |    |    |    └─Conv2d: 7-13            [-1, 128, 128, 128]       368,640
# |    |    |    |    |    |    └─BatchNorm2d: 7-14       [-1, 128, 128, 128]       256
# |    |    |    |    |    |    └─ReLU: 7-15              [-1, 128, 128, 128]       --
# |    |    |    |    └─ConvBlock: 5-18                   [-1, 128, 128, 128]       --
# |    |    |    |    |    └─Sequential: 6-6              [-1, 128, 128, 128]       --
# |    |    |    |    |    |    └─Conv2d: 7-16            [-1, 128, 128, 128]       147,456
# |    |    |    |    |    |    └─BatchNorm2d: 7-17       [-1, 128, 128, 128]       256
# |    |    |    |    |    |    └─ReLU: 7-18              [-1, 128, 128, 128]       --
# |    |    └─DecoderBlock: 3-4                           [-1, 64, 256, 256]        --
# |    |    |    └─Upsample: 4-103                        [-1, 128, 256, 256]       --
# |    |    |    └─Sequential: 4-104                      [-1, 64, 256, 256]        --
# |    |    |    |    └─ConvBlock: 5-19                   [-1, 64, 256, 256]        --
# |    |    |    |    |    └─Sequential: 6-7              [-1, 64, 256, 256]        --
# |    |    |    |    |    |    └─Conv2d: 7-19            [-1, 64, 256, 256]        110,592
# |    |    |    |    |    |    └─BatchNorm2d: 7-20       [-1, 64, 256, 256]        128
# |    |    |    |    |    |    └─ReLU: 7-21              [-1, 64, 256, 256]        --
# |    |    |    |    └─ConvBlock: 5-20                   [-1, 64, 256, 256]        --
# |    |    |    |    |    └─Sequential: 6-8              [-1, 64, 256, 256]        --
# |    |    |    |    |    |    └─Conv2d: 7-22            [-1, 64, 256, 256]        36,864
# |    |    |    |    |    |    └─BatchNorm2d: 7-23       [-1, 64, 256, 256]        128
# |    |    |    |    |    |    └─ReLU: 7-24              [-1, 64, 256, 256]        --
# |    |    └─DecoderBlock: 3-5                           [-1, 32, 512, 512]        --
# |    |    |    └─Upsample: 4-105                        [-1, 64, 512, 512]        --
# |    |    |    └─Sequential: 4-106                      [-1, 32, 512, 512]        --
# |    |    |    |    └─ConvBlock: 5-21                   [-1, 32, 512, 512]        --
# |    |    |    |    |    └─Sequential: 6-9              [-1, 32, 512, 512]        --
# |    |    |    |    |    |    └─Conv2d: 7-25            [-1, 32, 512, 512]        19,296
# |    |    |    |    |    |    └─BatchNorm2d: 7-26       [-1, 32, 512, 512]        64
# |    |    |    |    |    |    └─ReLU: 7-27              [-1, 32, 512, 512]        --
# |    |    |    |    └─ConvBlock: 5-22                   [-1, 32, 512, 512]        --
# |    |    |    |    |    └─Sequential: 6-10             [-1, 32, 512, 512]        --
# |    |    |    |    |    |    └─Conv2d: 7-28            [-1, 32, 512, 512]        9,216
# |    |    |    |    |    |    └─BatchNorm2d: 7-29       [-1, 32, 512, 512]        64
# |    |    |    |    |    |    └─ReLU: 7-30              [-1, 32, 512, 512]        --
# ├─Conv2d: 1-3                                           [-1, 7, 512, 512]         231
# ├─Softmax: 1-4                                          [-1, 7, 512, 512]         --
# =========================================================================================================
# Total params: 19,835,399
# Trainable params: 19,835,399
# Non-trainable params: 0
# Total mult-adds (G): 59.15
# =========================================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 708.00
# Params size (MB): 75.67
# Estimated Total Size (MB): 786.67
# =========================================================================================================
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# ├─GraphModuleImpl: 1-1                                  [[-1, 512, 16, 16]]       --
# ├─ResNet: 1                                             []                        --
# |    └─Conv2d: 2-1                                      [-1, 64, 256, 256]        9,408
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Conv2d: 2-2                                      [-1, 64, 256, 256]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─BatchNorm2d: 2-3                                 [-1, 64, 256, 256]        128
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─BatchNorm2d: 2-4                                 [-1, 64, 256, 256]        (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─ReLU: 2-5                                        [-1, 64, 256, 256]        --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─ReLU: 2-6                                        [-1, 64, 256, 256]        --
# ├─ResNet: 1                                             []                        --
# ...
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-74                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-75                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-76                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-77                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-78                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-79                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-80                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-81                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-82                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─Conv2d: 5-9                       [-1, 512, 16, 16]         131,072
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─Conv2d: 5-10                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Sequential: 4                          []                        --
# |    |    |    |    └─BatchNorm2d: 5-11                 [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Module: 4                              []                        --
# |    |    |    |    └─BatchNorm2d: 5-12                 [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-83                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-84                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-85                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-86                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-87                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-88                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-89                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-90                             [-1, 512, 16, 16]         --
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─Conv2d: 4-91                           [-1, 512, 16, 16]         2,359,296
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─Conv2d: 4-92                           [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─BatchNorm2d: 4-93                      [-1, 512, 16, 16]         1,024
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─BatchNorm2d: 4-94                      [-1, 512, 16, 16]         (recursive)
# ├─ResNet: 1                                             []                        --
# |    └─Sequential: 2                                    []                        --
# |    |    └─BasicBlock: 3                               []                        --
# |    |    |    └─ReLU: 4-95                             [-1, 512, 16, 16]         --
# ├─GraphModuleImpl: 1                                    []                        --
# |    └─Module: 2                                        []                        --
# |    |    └─Module: 3                                   []                        --
# |    |    |    └─ReLU: 4-96                             [-1, 512, 16, 16]         --
# ├─Decoder: 1-2                                          [-1, 32, 512, 512]        --
# |    └─ModuleList: 2                                    []                        --
# |    |    └─DecoderBlock: 3-1                           [-1, 512, 32, 32]         --
# |    |    |    └─Upsample: 4-97                         [-1, 512, 32, 32]         --
# |    |    |    └─Sequential: 4-98                       [-1, 512, 32, 32]         --
# |    |    |    |    └─ConvBlock: 5-13                   [-1, 512, 32, 32]         --
# |    |    |    |    |    └─Sequential: 6-1              [-1, 512, 32, 32]         --
# |    |    |    |    |    |    └─Conv2d: 7-1             [-1, 512, 32, 32]         3,538,944
# |    |    |    |    |    |    └─BatchNorm2d: 7-2        [-1, 512, 32, 32]         1,024
# |    |    |    |    |    |    └─ReLU: 7-3               [-1, 512, 32, 32]         --
# |    |    |    |    └─ConvBlock: 5-14                   [-1, 512, 32, 32]         --
# |    |    |    |    |    └─Sequential: 6-2              [-1, 512, 32, 32]         --
# |    |    |    |    |    |    └─Conv2d: 7-4             [-1, 512, 32, 32]         2,359,296
# |    |    |    |    |    |    └─BatchNorm2d: 7-5        [-1, 512, 32, 32]         1,024
# |    |    |    |    |    |    └─ReLU: 7-6               [-1, 512, 32, 32]         --
# |    |    └─DecoderBlock: 3-2                           [-1, 256, 64, 64]         --
# |    |    |    └─Upsample: 4-99                         [-1, 512, 64, 64]         --
# |    |    |    └─Sequential: 4-100                      [-1, 256, 64, 64]         --
# |    |    |    |    └─ConvBlock: 5-15                   [-1, 256, 64, 64]         --
# |    |    |    |    |    └─Sequential: 6-3              [-1, 256, 64, 64]         --
# |    |    |    |    |    |    └─Conv2d: 7-7             [-1, 256, 64, 64]         1,474,560
# |    |    |    |    |    |    └─BatchNorm2d: 7-8        [-1, 256, 64, 64]         512
# |    |    |    |    |    |    └─ReLU: 7-9               [-1, 256, 64, 64]         --
# |    |    |    |    └─ConvBlock: 5-16                   [-1, 256, 64, 64]         --
# |    |    |    |    |    └─Sequential: 6-4              [-1, 256, 64, 64]         --
# |    |    |    |    |    |    └─Conv2d: 7-10            [-1, 256, 64, 64]         589,824
# |    |    |    |    |    |    └─BatchNorm2d: 7-11       [-1, 256, 64, 64]         512
# |    |    |    |    |    |    └─ReLU: 7-12              [-1, 256, 64, 64]         --
# |    |    └─DecoderBlock: 3-3                           [-1, 128, 128, 128]       --
# |    |    |    └─Upsample: 4-101                        [-1, 256, 128, 128]       --
# |    |    |    └─Sequential: 4-102                      [-1, 128, 128, 128]       --
# |    |    |    |    └─ConvBlock: 5-17                   [-1, 128, 128, 128]       --
# |    |    |    |    |    └─Sequential: 6-5              [-1, 128, 128, 128]       --
# |    |    |    |    |    |    └─Conv2d: 7-13            [-1, 128, 128, 128]       368,640
# |    |    |    |    |    |    └─BatchNorm2d: 7-14       [-1, 128, 128, 128]       256
# |    |    |    |    |    |    └─ReLU: 7-15              [-1, 128, 128, 128]       --
# |    |    |    |    └─ConvBlock: 5-18                   [-1, 128, 128, 128]       --
# |    |    |    |    |    └─Sequential: 6-6              [-1, 128, 128, 128]       --
# |    |    |    |    |    |    └─Conv2d: 7-16            [-1, 128, 128, 128]       147,456
# |    |    |    |    |    |    └─BatchNorm2d: 7-17       [-1, 128, 128, 128]       256
# |    |    |    |    |    |    └─ReLU: 7-18              [-1, 128, 128, 128]       --
# |    |    └─DecoderBlock: 3-4                           [-1, 64, 256, 256]        --
# |    |    |    └─Upsample: 4-103                        [-1, 128, 256, 256]       --
# |    |    |    └─Sequential: 4-104                      [-1, 64, 256, 256]        --
# |    |    |    |    └─ConvBlock: 5-19                   [-1, 64, 256, 256]        --
# |    |    |    |    |    └─Sequential: 6-7              [-1, 64, 256, 256]        --
# |    |    |    |    |    |    └─Conv2d: 7-19            [-1, 64, 256, 256]        110,592
# |    |    |    |    |    |    └─BatchNorm2d: 7-20       [-1, 64, 256, 256]        128
# |    |    |    |    |    |    └─ReLU: 7-21              [-1, 64, 256, 256]        --
# |    |    |    |    └─ConvBlock: 5-20                   [-1, 64, 256, 256]        --
# |    |    |    |    |    └─Sequential: 6-8              [-1, 64, 256, 256]        --
# |    |    |    |    |    |    └─Conv2d: 7-22            [-1, 64, 256, 256]        36,864
# |    |    |    |    |    |    └─BatchNorm2d: 7-23       [-1, 64, 256, 256]        128
# |    |    |    |    |    |    └─ReLU: 7-24              [-1, 64, 256, 256]        --
# |    |    └─DecoderBlock: 3-5                           [-1, 32, 512, 512]        --
# |    |    |    └─Upsample: 4-105                        [-1, 64, 512, 512]        --
# |    |    |    └─Sequential: 4-106                      [-1, 32, 512, 512]        --
# |    |    |    |    └─ConvBlock: 5-21                   [-1, 32, 512, 512]        --
# |    |    |    |    |    └─Sequential: 6-9              [-1, 32, 512, 512]        --
# |    |    |    |    |    |    └─Conv2d: 7-25            [-1, 32, 512, 512]        19,296
# |    |    |    |    |    |    └─BatchNorm2d: 7-26       [-1, 32, 512, 512]        64
# |    |    |    |    |    |    └─ReLU: 7-27              [-1, 32, 512, 512]        --
# |    |    |    |    └─ConvBlock: 5-22                   [-1, 32, 512, 512]        --
# |    |    |    |    |    └─Sequential: 6-10             [-1, 32, 512, 512]        --
# |    |    |    |    |    |    └─Conv2d: 7-28            [-1, 32, 512, 512]        9,216
# |    |    |    |    |    |    └─BatchNorm2d: 7-29       [-1, 32, 512, 512]        64
# |    |    |    |    |    |    └─ReLU: 7-30              [-1, 32, 512, 512]        --
# ├─Conv2d: 1-3                                           [-1, 7, 512, 512]         231
# ├─Softmax: 1-4                                          [-1, 7, 512, 512]         --
# =========================================================================================================
# Total params: 19,835,399
# Trainable params: 19,835,399
# Non-trainable params: 0
# Total mult-adds (G): 59.15
# =========================================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 708.00
# Params size (MB): 75.67
# Estimated Total Size (MB): 786.67
# =========================================================================================================
